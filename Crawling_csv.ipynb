# %%
import tweepy
import csv
from tweepy import OAuthHandler
import string
import pandas as pd

access_token = "1366538464578052099-R7jB0ja6oZ7lguZgDjqpp3sVuuMdVm"
access_token_secret = "SY0pESolMa6ALidIlBrDhapLBBQ9e9IkibEtNl8mgAd5a"
api_key = "Vorv3pDFrbIc6jGDBqO16gT99"
api_key_secret = "CeT3lAJakQ8h3kdVYzZk0QsDkCKJMF1S5D2iqFBYD1d3GuBVzm"

auth = tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

search_key = "tunda pemilu"
csvFile = open("data23-12-22"+".csv", "a+", encoding="utf-8")
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q=search_key, lang="id").items(2000):
    print(tweet.created_at,tweet.author.screen_name,tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.author.screen_name, tweet.text])
# Out:
# 2022-12-23 03:13:42 m_syaf77 RT @Tan_Mar3M: Ini poling bisa jadi pemicu tunda pemilu 😃 https://t.co/DTH82iechz
# 2022-12-23 03:03:27 IwanDar71668133 RT @democrazymedia: Bank Dunia Ungkap Harga Beras RI Paling Mahal, Klaim Jokowi Diungkit Kembali
# https://t.co/GZVLFeQanF
# 2022-12-23 03:01:06 79_biru RT @sehat_roemah: BISA MEMICU KONFLIK SARA atau sengaja tuk meloloskan CIPTA KONDISI DARURAT demi DEKRIT TUNDA PEMILU? @mohmahfudmd https:/…
# 2022-12-23 02:57:23 RomBedul RT @OposisiCerdas: Jokowi Minta Pemilu 2024 Sportif, Demokrat Minta Jangan Ada Lagi Upaya Tunda Pemilu
# https://t.co/RSqIOEFOLw
# 2022-12-23 02:45:50 akhirrzaman78 RT @sehat_roemah: BISA MEMICU KONFLIK SARA atau sengaja tuk meloloskan CIPTA KONDISI DARURAT demi DEKRIT TUNDA PEMILU? @mohmahfudmd https:/…
# 2022-12-23 02:45:22 MonCha65938734 RT @rockyu01: @caul_tanjung Dimulai d tahapan tunda pemilu
# 2022-12-23 02:45:17 MonCha65938734 RT @makrete: @caul_tanjung Hubungan nya apa  gara2 ketua KPU cabul pemilu di tunda?
# ...
